# %%
dbutils.notebook.run("/Workspace/Users/vaddibharath307@gmail.com/NovaCart-miniproject/002-silver/nb_silver_customers",3600)

dbutils.notebook.run("/Workspace/Users/vaddibharath307@gmail.com/NovaCart-miniproject/002-silver/nb_silver_exchange_rates",3600)

dbutils.notebook.run("/Workspace/Users/vaddibharath307@gmail.com/NovaCart-miniproject/002-silver/nb_silver_order_items",3600)

dbutils.notebook.run("/Workspace/Users/vaddibharath307@gmail.com/NovaCart-miniproject/002-silver/nb_silver_orders",3600)

dbutils.notebook.run("/Workspace/Users/vaddibharath307@gmail.com/NovaCart-miniproject/002-silver/nb_silver_products",3600)
