# %%
dbutils.notebook.run("/Workspace/Users/vaddibharath307@gmail.com/NovaCart-miniproject/003-gold/nb_gold_dim",3600)

dbutils.notebook.run("/Workspace/Users/vaddibharath307@gmail.com/NovaCart-miniproject/003-gold/nb_gold_facts",3600)

dbutils.notebook.run("/Workspace/Users/vaddibharath307@gmail.com/NovaCart-miniproject/003-gold/nb_gold_datacube",3600)

dbutils.notebook.run("/Workspace/Users/vaddibharath307@gmail.com/NovaCart-miniproject/003-gold/nb_gold_kpi",3600)
